# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe1.pkl','rb'))

# %%
# Assume user input
test_input2 = np.array([8,1]).reshape(1, -1) # only depend on cgpa

# %%
result = pipe.predict(test_input2)
# Out:
# C:\Users\Aditya\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
if result == 1:
    print('placement')
else:
    print('Not placement')
# Out:
# placed
